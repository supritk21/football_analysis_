# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="q1Nakx9XOXygyhur0oMT")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(10)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-10 in yolov5pytorch:: 100%|██████████| 636/636 [00:00<00:00, 6370.88it/s]

# %%
dataset.location
# Out:
# '/home/hb/Documents/placement_proj/FootBallAnalysis/football-players-detection-10'

# %%
import shutil

shutil.move('football-players-detection-10/train', 'football-players-detection-1/football-players-detection-10/train')
shutil.move('football-players-detection-10/valid', 'football-players-detection-1/football-players-detection-10/valid')
shutil.move('football-players-detection-10/test', 'football-players-detection-1/football-players-detection-10/test')
# Out:
# 'football-players-detection-10/football-players-detection-10/test'

# %% [markdown]
# Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt  data=/home/hb/Documents/placement_proj/FootBallAnalysis/football-players-detection-1/data.yaml epochs=100 imgsz=640
# Out:
# /home/hb/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics YOLOv8.2.71 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24115MiB)
# ...

# %%
import os
os.mkdir('models')
shutil.copy('runs/detect/train2/weights/best.pt', 'models/')
shutil.copy('runs/detect/train2/weights/last.pt', 'models/')
# Out:
# 'models/last.pt'
